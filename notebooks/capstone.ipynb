# %%
import os

folder = "../data/raw/extracted_csv"

files = os.listdir(folder)

for file in files:
    print(file)
# Out:
# 01-January-csv.zip
# main.csv
# releases.csv
# releases_awards.csv
# releases_awards_suppliers.csv
# releases_contracts.csv
# releases_contracts_amendments.csv
# releases_contracts_documents.csv
# releases_contracts_items.csv
# releases_parties.csv
# releases_parties_details_classifications.csv
# releases_relatedProcesses.csv
# releases_tender_documents.csv
# releases_tender_items.csv
# releases_tender_lots.csv
# releases_tender_tenderers.csv

# %%
import pandas as pd

contracts = pd.read_csv("../data/raw/extracted_csv/releases_contracts.csv")

# %%
contracts.shape
# Out:
# (1666, 14)

# %%
contracts.columns.tolist()
# Out:
# ['_link',
#  '_link_releases',
#  '_link_main',
#  'id',
#  'awardID',
#  'title',
#  'description',
#  'status',
#  'dateSigned',
#  'period_startDate',
#  'period_endDate',
#  'period_durationInDays',
#  'value_amount',
#  'value_currency']

# %%
contracts.head()
# Out:
#                       _link _link_releases  _link_main                    id  \
# 0  0.releases.1.contracts.0   0.releases.1           0  C1013980242023000025
# 1  0.releases.2.contracts.0   0.releases.2           0  C1013980242023000024
# 2  0.releases.3.contracts.0   0.releases.3           0  C1013980242024000020
# 3  0.releases.5.contracts.0   0.releases.5           0  C1203356722024000045
# 4  0.releases.6.contracts.0   0.releases.6           0  C1203356722024000045
#
#                                 awardID  \
# 0  ab81a140-69f4-4398-ba86-4e154ca92039
# 1  d8bd03c5-cb2e-4ff3-a898-7b9a2c9610aa
# 2  c714a6c2-278d-464c-a650-10f8853129f3
# 3  7cddff0f-62bb-42aa-ac06-26ee7de74336
# 4  7cddff0f-62bb-42aa-ac06-26ee7de74336
#
#                                                title  \
# 0                                   LOCATION CANTINE
# 1         Refreshment of hospital staff and visitors
# 2                Re-Advertising of Cleaning services
# ...
